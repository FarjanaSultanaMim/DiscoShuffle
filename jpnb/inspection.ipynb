# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# # Essay Scoring

# %% [markdown]
# ## DI-aware

# %%
def inspect(m, t = "No description", ax = None, vals = "loss val_loss".split()):
    l = pickle.load(open("../{}/logs_f0.pickle".format(m), "rb"))
    p = dict([p.strip().split("=", 1) for p in open("../{}/param.txt".format(m))])
    df_b, df_e = pd.DataFrame(l["logs_b"]), pd.DataFrame(l["logs_e"])
    df_e[vals].plot(ylim=[0, 0.2], title=t, ax=ax)
    print(p)
    print(df_e[vals].describe())

# %%
# This setting is weird because DI embeddings are fixed
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
inspect("output/46392cffc6de88b365408aeb30f5415b", "DI-aware, no pretraining (dropout=0.7)", ax=axs[0])
inspect("output/ebb929454385723f06b415f9164590c6", "DI-aware, no pretraining (dropout=0.5)", ax=axs[1])
inspect("output/6640830a05efb4a9dc8eebd1a1e79706", "DI-aware, no pretraining (dropout=0.3)", ax=axs[2])
# Out:
# {'aggr_grudim': '100', 'att': 'False', 'clipnorm': '5.0', 'di_aware': 'True', 'dropout': '0.7', 'emb_dim': '50', 'emb_fix': 'True', 'enc_fix': 'False', 'encdim': 'None', 'model_type': 'nea', 'mot': 'True', 'preenc': 'None', 'pretrained': 'True', 'pseq': 'True', 'pseq_embdim': '16', 'pseq_encdim': '64'}
#             loss   val_loss
# count  16.000000  16.000000
# mean    0.827905   0.765423
# std     1.891869   1.554574
# min     0.194814   0.198239
# 25%     0.216052   0.289767
# 50%     0.256125   0.394856
# 75%     0.369028   0.453955
# max     7.817434   6.577231
# {'aggr_grudim': '100', 'att': 'False', 'clipnorm': '5.0', 'di_aware': 'True', 'dropout': '0.5', 'emb_dim': '50', 'emb_fix': 'True', 'enc_fix': 'False', 'encdim': 'None', 'model_type': 'nea', 'mot': 'True', 'preenc': 'None', 'pretrained': 'True', 'pseq': 'True', 'pseq_embdim': '16', 'pseq_encdim': '64'}
#             loss   val_loss
# count  15.000000  15.000000
# mean    0.791733   0.435874
# ...

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
inspect("output/a5513c4c0d03ab93fd32865ea4bf48dd", "DI-aware, pretraining (do=0.7)", ax=axs[0])
inspect("output/3b922ef5f8336544d1a117ea4a5ce4ce", "DI-aware, pretraining (do=0.5)", ax=axs[1])
inspect("output/c4055019c9cf88ec115e81f9d1a47490", "DI-aware, pretraining (do=0.3)", ax=axs[2])
# Out:
# {'aggr_grudim': '100', 'att': 'False', 'clipnorm': '5.0', 'di_aware': 'True', 'dropout': '0.7', 'emb_dim': '50', 'emb_fix': 'False', 'enc_fix': 'False', 'encdim': 'None', 'model_type': 'nea', 'mot': 'True', 'preenc': 'output_enc/clipnorm=5.0_dropout=0.7_emb_dim=50_emb_fix=False_enc_fix=False_model_type=nea_mot=True_pretrained=False_shuf=di', 'pretrained': 'False', 'pseq': 'True', 'pseq_embdim': '16', 'pseq_encdim': '64'}
#             loss   val_loss
# count  38.000000  38.000000
# mean    0.324698   0.204893
# std     0.641758   0.101153
# min     0.177023   0.149717
# 25%     0.182330   0.156670
# 50%     0.189604   0.163624
# 75%     0.239920   0.192955
# max     4.156113   0.685853
# ...

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
inspect("output/1d02baaca5118879ee895dc7973b9645", "DI-aware, pretraining (fixed, do=0.7)", ax=axs[0])
inspect("output/2c8309eb1d52b3f0f21abb7039b33b2e", "DI-aware, pretraining (fixed, do=0.5)", ax=axs[1])
inspect("output/d7f357c8922e8a47a69b3c0ca0cb3e34", "DI-aware, pretraining (fixed, do=0.3)", ax=axs[2])
# Out:
# {'aggr_grudim': '100', 'att': 'False', 'clipnorm': '5.0', 'di_aware': 'True', 'dropout': '0.7', 'emb_dim': '50', 'emb_fix': 'True', 'enc_fix': 'True', 'encdim': 'None', 'model_type': 'nea', 'mot': 'True', 'preenc': 'output_enc/clipnorm=5.0_dropout=0.7_emb_dim=50_emb_fix=False_enc_fix=False_model_type=nea_mot=True_pretrained=False_shuf=di', 'pretrained': 'False', 'pseq': 'True', 'pseq_embdim': '16', 'pseq_encdim': '64'}
#             loss   val_loss
# count  38.000000  38.000000
# mean    0.365974   0.230254
# std     0.825887   0.183223
# min     0.176570   0.148849
# 25%     0.185622   0.156966
# 50%     0.197179   0.175800
# 75%     0.260128   0.229322
# max     5.301606   1.257647
# ...

# %% [markdown]
# ## Non DI-aware

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
inspect("output/cde3e253163f10bde9887a702811182a", "non DI, no pretraining (dropout=0.7)", ax=axs[0])
inspect("output/942caf5c987d95be65e25d3064123f62", "non DI, no pretraining (dropout=0.5)", ax=axs[1])
inspect("output/a4609b3116ca6ae30db134ab14ab61f6", "non DI, no pretraining (dropout=0.3)", ax=axs[2])
# Out:
# {'aggr_grudim': '300', 'att': 'False', 'clipnorm': '5.0', 'di_aware': 'False', 'dropout': '0.7', 'emb_dim': '50', 'emb_fix': 'True', 'enc_fix': 'False', 'encdim': 'None', 'model_type': 'nea', 'mot': 'True', 'preenc': 'None', 'pretrained': 'True', 'pseq': 'True', 'pseq_embdim': '16', 'pseq_encdim': '400', 'score_type': 'Organization'}
#             loss   val_loss
# count  56.000000  56.000000
# mean    0.020419   0.026781
# std     0.006972   0.006874
# min     0.013032   0.021034
# 25%     0.015612   0.022093
# 50%     0.018355   0.024450
# 75%     0.022895   0.028532
# max     0.051684   0.053275
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-a1332bfa4367> in <module>
#       1 fig, axs = plt.subplots(1, 3, figsize=(12, 4))
#       2 inspect("output/cde3e253163f10bde9887a702811182a", "non DI, no pretraining (dropout=0.7)", ax=axs[0])
# ...

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
inspect("output/681f9b6f1dfd4c7718cb4e85d2285c25", "non DI, pretraining (dropout=0.7)", ax=axs[0])
inspect("output/cbc428f99e04b33c2dcb221e7331e07d", "non DI, pretraining (dropout=0.5)", ax=axs[1])
inspect("output/03c5a94c73f332f78579bb40ed443d53", "non DI, pretraining (dropout=0.3)", ax=axs[2])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-56ad13d19c32> in <module>
#       1 fig, axs = plt.subplots(1, 3, figsize=(12, 4))
# ----> 2 inspect("output/681f9b6f1dfd4c7718cb4e85d2285c25", "non DI, pretraining (dropout=0.7)", ax=axs[0])
#       3 inspect("output/cbc428f99e04b33c2dcb221e7331e07d", "non DI, pretraining (dropout=0.5)", ax=axs[1])
#       4 inspect("output/03c5a94c73f332f78579bb40ed443d53", "non DI, pretraining (dropout=0.3)", ax=axs[2])
#
# <ipython-input-46-09300f4ec7d5> in inspect(m, t, ax, vals)
#       1 def inspect(m, t = "No description", ax = None, vals = "loss val_loss".split()):
# ----> 2     l = pickle.load(open("../{}/logs_f0.pickle".format(m), "rb"))
#       3     p = dict([p.strip().split("=", 1) for p in open("../{}/param.txt".format(m))])
#       4     df_b, df_e = pd.DataFrame(l["logs_b"]), pd.DataFrame(l["logs_e"])
# ...

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
inspect("output/3549d721dc569f3840c6e0435a39446b", "non DI, pretraining (fixed,do=0.7)", ax=axs[0])
inspect("output/b0733c2088db7182bf669d6ab63c6e7d", "non DI, pretraining (fixed,do=0.5)", ax=axs[1])
inspect("output/f4fdd60b16cdffec9a94802838c9a36a", "non DI, pretraining (fixed,do=0.3)", ax=axs[2])
# Out:
# {'aggr_grudim': '100', 'att': 'False', 'clipnorm': '5.0', 'di_aware': 'False', 'dropout': '0.7', 'emb_dim': '50', 'emb_fix': 'True', 'enc_fix': 'True', 'encdim': 'None', 'model_type': 'nea', 'mot': 'True', 'preenc': 'output_enc/clipnorm=5.0_dropout=0.7_emb_dim=50_emb_fix=False_enc_fix=False_model_type=nea_mot=True_pretrained=False_shuf=sentence', 'pretrained': 'False', 'pseq': 'True', 'pseq_embdim': '16', 'pseq_encdim': '64'}
#             loss   val_loss
# count  33.000000  33.000000
# mean    0.408551   0.279229
# std     0.880683   0.403864
# min     0.181927   0.153509
# 25%     0.192607   0.157686
# 50%     0.206041   0.172197
# 75%     0.283717   0.214239
# max     5.252208   2.450344
# ...

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

l = pickle.load(open("../output_enc/d=0.1_m=nea_pre=False_embfix=False_embdim=50_mot=False/logs.pickle", "rb"))
df_b, df_e = pd.DataFrame(l["logs_b"]), pd.DataFrame(l["logs_e"])
df_e[["loss",  "acc", "val_loss", "val_acc"]].plot(ax=axs[0])
print(df_e[["loss", "acc", "val_loss", "val_acc"]].describe())

l = pickle.load(open("../output_enc/d=0.5_m=nea_pre=False_embfix=False_embdim=50_mot=False/logs.pickle", "rb"))
df_b, df_e = pd.DataFrame(l["logs_b"]), pd.DataFrame(l["logs_e"])
df_e[["loss",  "acc", "val_loss", "val_acc"]].plot(ax=axs[1])
print(df_e[["loss", "acc",  "val_loss", "val_acc"]].describe())

l = pickle.load(open("../output_enc/d=0.9_m=nea_pre=False_embfix=False_embdim=50_mot=False/logs.pickle", "rb"))
df_b, df_e = pd.DataFrame(l["logs_b"]), pd.DataFrame(l["logs_e"])
df_e[["loss",  "acc", "val_loss", "val_acc"]].plot(ax=axs[2])
print(df_e[["loss", "acc",  "val_loss", "val_acc"]].describe())
# Out:
#            loss       acc  val_loss   val_acc
# count  8.000000  8.000000  8.000000  8.000000
# mean   0.210701  0.896930  1.169013  0.635950
# std    0.246479  0.145605  0.432690  0.017175
# min    0.020451  0.589936  0.616331  0.617126
# 25%    0.033786  0.865250  0.742966  0.619587
# 50%    0.088042  0.969242  1.278502  0.637057
# 75%    0.321993  0.989758  1.564865  0.643824
# max    0.670793  0.996432  1.612282  0.660433
#             loss        acc   val_loss    val_acc
# count  11.000000  11.000000  11.000000  11.000000
# mean    0.383819   0.824274   0.772485   0.619963
# std     0.221750   0.151971   0.128019   0.053573
# min     0.097718   0.505155   0.594349   0.510309
# 25%     0.202640   0.773840   0.687322   0.597938
# 50%     0.358846   0.871134   0.741374   0.644330
# 75%     0.565334   0.933634   0.857503   0.652062
# max     0.700667   0.970361   0.981049   0.670103
#             loss        acc   val_loss    val_acc
# ...

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
inspect("output/78ee43c68de47a7a27ab9e9cfafb5754", "Pretraining, fixed (do=0.7)", ax=axs[0])
inspect("output/4ac62c0cb43370225f5e0dc763380c91", "Pretraining, fixed (do=0.5)", ax=axs[1])
inspect("output/eb40209496004f29ca30acb28e49c665", "Pretraining, fixed (do=0.3)", ax=axs[2])
# Out:
# {'aggr_grudim': '100', 'att': 'False', 'clipnorm': '5.0', 'di_aware': 'False', 'dropout': '0.5', 'emb_dim': '50', 'emb_fix': 'True', 'enc_fix': 'True', 'encdim': 'None', 'model_type': 'nea', 'mot': 'True', 'preenc': 'output_enc/a87b827fa7c5151192542ecb2c3af4d2', 'pretrained': 'False', 'pseq': 'True', 'pseq_embdim': '16', 'pseq_encdim': '64'}
#             loss   val_loss
# count  45.000000  45.000000
# mean    0.308738   0.207388
# std     0.610148   0.098778
# min     0.174275   0.150616
# 25%     0.180962   0.155060
# 50%     0.189395   0.170071
# 75%     0.231489   0.208366
# max     4.289656   0.709766
# {'aggr_grudim': '100', 'att': 'False', 'clipnorm': '5.0', 'di_aware': 'False', 'dropout': '0.3', 'emb_dim': '50', 'emb_fix': 'True', 'enc_fix': 'True', 'encdim': 'None', 'model_type': 'nea', 'mot': 'True', 'preenc': 'output_enc/a87b827fa7c5151192542ecb2c3af4d2', 'pretrained': 'False', 'pseq': 'True', 'pseq_embdim': '16', 'pseq_encdim': '64'}
#             loss   val_loss
# ...

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
inspect("output/bd5703bed929cdc741144b667e9d2cb8", "Pretraining (do=0.7)", ax=axs[0])
inspect("output/505f27a65f5beb90d4533cd220f228e8", "Pretraining (do=0.5)", ax=axs[1])
inspect("output/e0ab2e7b43b37719666bb6e1b0e58e10", "Pretraining (do=0.3)", ax=axs[2])
# Out:
# {'aggr_grudim': '100', 'att': 'False', 'clipnorm': '5.0', 'di_aware': 'False', 'dropout': '0.3', 'emb_dim': '50', 'emb_fix': 'False', 'enc_fix': 'False', 'encdim': 'None', 'model_type': 'nea', 'mot': 'True', 'preenc': 'output_enc/a87b827fa7c5151192542ecb2c3af4d2', 'pretrained': 'False', 'pseq': 'True', 'pseq_embdim': '16', 'pseq_encdim': '64'}
#             loss   val_loss
# count  26.000000  26.000000
# mean    0.396561   0.227121
# std     0.802490   0.101800
# min     0.183030   0.156259
# 25%     0.197939   0.167384
# 50%     0.215308   0.181007
# 75%     0.277443   0.241181
# max     4.319513   0.609087
# {'aggr_grudim': '100', 'att': 'False', 'clipnorm': '5.0', 'di_aware': 'False', 'dropout': '0.5', 'emb_dim': '50', 'emb_fix': 'False', 'enc_fix': 'False', 'encdim': 'None', 'model_type': 'nea', 'mot': 'True', 'preenc': 'output_enc/a87b827fa7c5151192542ecb2c3af4d2', 'pretrained': 'False', 'pseq': 'True', 'pseq_embdim': '16', 'pseq_encdim': '64'}
#             loss   val_loss
# ...

# %% [markdown]
# # Encoder pretraining

# %% [markdown]
# ## DI shuffle

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
#inspect("output_enc/da6836f961365a7b348281a00e48bc34", "DI shuffle (do=0.3)", ax=axs[0], vals="loss val_loss acc val_acc".split())
#inspect("output_enc/6abbf82fd461ebcd2ac61867427b2a1e", "DI shuffle (do=0.5)", ax=axs[1], vals="loss val_loss acc val_acc".split())
#inspect("output_enc/a87b827fa7c5151192542ecb2c3af4d2", "DI shuffle (do=0.7)", ax=axs[2], vals="loss val_loss acc val_acc".split())
inspect("output_enc/9780456c95e7c048e2501106fd40c716", "DI. shuffle (do=0.7)", ax=axs[2], vals="loss val_loss acc val_acc".split())
# Out:
# {'aggr_grudim': '300', 'att': 'False', 'clipnorm': '5.0', 'dropout': '0.7', 'emb_dim': '50', 'emb_fix': 'False', 'enc_fix': 'False', 'encdim': 'None', 'model_type': 'nea', 'mot': 'True', 'pretrained': 'False', 'shuf': 'di'}
#             loss   val_loss        acc    val_acc
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.458788   0.555148   0.726215   0.678357
# std     0.282417   0.149881   0.192163   0.170494
# min     0.046360   0.342721   0.499590   0.471616
# 25%     0.145541   0.402735   0.554274   0.508051
# 50%     0.630851   0.636973   0.635650   0.623635
# 75%     0.681175   0.691989   0.940743   0.870906
# max     0.792948   0.727556   0.982933   0.879913

# %% [markdown]
# ## Sentence shuffle

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
# inspect("output_enc/da6836f961365a7b348281a00e48bc34", "DI shuffle (do=0.3)", ax=axs[0], vals="loss val_loss acc val_acc".split())
# inspect("output_enc/clipnorm=5.0_dropout=0.5_emb_dim=50_emb_fix=False_enc_fix=False_model_type=nea_mot=True_pretrained=False_shuf=sentence", "Sent. shuffle (do=0.5)", ax=axs[1], vals="loss val_loss acc val_acc".split())
# inspect("output_enc/clipnorm=5.0_dropout=0.7_emb_dim=50_emb_fix=False_enc_fix=False_model_type=nea_mot=True_pretrained=False_shuf=sentence", "Sent. shuffle (do=0.7)", ax=axs[2], vals="loss val_loss acc val_acc".split())
inspect("output_enc/c2c4d855a06224fd1096834eed11920d", "Sent. shuffle (do=0.7)", ax=axs[2], vals="loss val_loss acc val_acc".split())
# Out:
# {'aggr_grudim': '300', 'att': 'False', 'clipnorm': '5.0', 'dropout': '0.7', 'emb_dim': '50', 'emb_fix': 'False', 'enc_fix': 'False', 'encdim': 'None', 'model_type': 'nea', 'mot': 'True', 'pretrained': 'False', 'shuf': 'sentence'}
#            loss  val_loss       acc   val_acc
# count  7.000000  7.000000  7.000000  7.000000
# mean   0.469463  0.592627  0.767048  0.708515
# std    0.127080  0.031974  0.097510  0.032365
# min    0.324805  0.565203  0.587520  0.639738
# 25%    0.378542  0.565639  0.727267  0.707151
# 50%    0.445648  0.584458  0.788913  0.721616
# 75%    0.537008  0.609020  0.835609  0.725710
# max    0.684688  0.649412  0.867149  0.732533

# %% [markdown]
# ## DI shuffle + DI-aware

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
inspect("output_enc/clipnorm=5.0_dropout=0.7_emb_dim=50_emb_fix=False_enc_fix=False_model_type=nea_mot=True_pretrained=False_shuf=di", "DI shuffle, DI-aware (do=0.7)", ax=axs[2], vals="loss val_loss acc val_acc".split())
# Out:
# {}
#             loss   val_loss        acc  \
# count  23.000000  23.000000  23.000000
# mean    0.342596   0.423323   0.797076
# std     0.291690   0.212430   0.197337
# min     0.019996   0.195649   0.500546
# 25%     0.049140   0.230204   0.593050
# 50%     0.270919   0.360671   0.885035
# 75%     0.663106   0.680664   0.981977
# max     0.693863   0.695105   0.992900
#
#          val_acc
# count  23.000000
# mean    0.753892
# std     0.202876
# min     0.424672
# 25%     0.533024
# 50%     0.844978
# 75%     0.926856
# max     0.936681

# %% [markdown]
# # Batch-wise loss

# %%
m = "clipnorm=5.0_dropout=0.7_emb_dim=50_emb_fix=False_enc_fix=False_model_type=nea_mot=False_pretrained=False_shuf=di"
l = pickle.load(open("../output_enc/{}/logs.pickle".format(m), "rb"))
df_b, df_e = pd.DataFrame(l["logs_b"]), pd.DataFrame(l["logs_e"])
df_b[["loss", "acc"]].rolling(window=3).mean().plot()

# %% [markdown]
# # Embedding

# %%
emb = pickle.load(open("../test.pickle", "rb"))

def find_similar_words(tw):
    sims = dict(zip(emb, [np.dot(emb[w], emb[tw])/(np.linalg.norm(emb[w])*np.linalg.norm(emb[tw])) for w in emb]))
    sims = sorted(sims.items(),key=lambda x: x[1], reverse=True)
    return list(sims)[:50]

find_similar_words("keyboard")
# Out:
# /home/naoya-i/py36/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in float_scalars
#   after removing the cwd from sys.path.
# [('keyboard', 1.0000001),
#  ('openness', 0.53291917),
#  ('metropolitian', 0.5129662),
#  ('icebergs', 0.4896725),
#  ('boards', 0.4857278),
#  ('accordly', 0.4800825),
#  ('lotus', 0.47589016),
#  ('epoc', 0.47370464),
#  ('minted', 0.47177768),
#  ('reap', 0.46675998),
#  ('fancied', 0.46480057),
#  ('attire', 0.45990974),
#  ('financiate', 0.45434886),
#  ('walloons', 0.44975245),
#  ('residences', 0.44908282),
#  ('rationale', 0.44746196),
#  ('merete', 0.44515517),
#  ('lumpkin', 0.44494966),
#  ('stamp', 0.44426972),
#  ("mum's", 0.44107527),
#  ('weekly', 0.43951276),
#  ('expansionary', 0.4388697),
#  ('hat', 0.43776745),
#  ("'as", 0.4365851),
#  ('shapely', 0.4364258),
#  ('cradit', 0.43575105),
#  ('psyche', 0.43537787),
#  ('bordeom', 0.43477193),
#  ('ahving', 0.43380433),
# ...
